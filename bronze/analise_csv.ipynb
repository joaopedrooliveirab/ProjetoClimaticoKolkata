# %%
import pandas as pd

df_clima = pd.read_csv("../archive/kolkata_weather_jan_june_2026.csv")
display(df_clima)

# verificar as informações da tabela
display(df_clima.info())

display(df_clima.duplicated("precipitation_sum"))
# Out:
#             time  weather_code  temperature_2m_mean  temperature_2m_max  \
# 0     2021-06-30            65                 29.9                33.4
# 1     2021-07-01            63                 29.8                33.4
# 2     2021-07-02            63                 29.2                32.2
# 3     2021-07-03            63                 29.2                32.9
# 4     2021-07-04            63                 28.6                32.1
# ...          ...           ...                  ...                 ...
# 1822  2026-06-26            63                 29.8                32.9
# 1823  2026-06-27            53                 30.2                34.3
# 1824  2026-06-28            63                 29.7                32.8
# 1825  2026-06-29            63                 29.2                34.0
# 1826  2026-06-30            61                 28.1                32.3
#
#       temperature_2m_min  precipitation_sum  rain_sum  precipitation_hours  \
# ...
